# %%
import json
from collections import defaultdict
import tensorflow as tf
from tensorflow.keras.optimizers import *
import random
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\jayni\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X = []
with open('filter_all_t.json',"r+") as f:
    X = json.load(f)

# %%
X.keys()
# Out:
# dict_keys(['train', 'val', 'test'])

# %%
Xtrain = []
Xvalid = []
Xtest = []

# %%
usersVisitedByRestaurant  = defaultdict(set)
restaurantsVisitedByUser = defaultdict(set)

# %%
reviewsPerUser = defaultdict(int)
reviewsPerRestaurant = defaultdict(int)
ratingPerUser =  defaultdict(list)
ratingPerRestaurant = defaultdict(list)
for x in X['train']+X['val']+X['test']:
    reviewsPerUser[x['user_id']]+=1
    reviewsPerRestaurant[x['business_id']]+=1
    
avgReviewsPerUser = np.mean([reviewsPerUser[k] for k in reviewsPerUser])
avgReviewsPerRestaurant = np.mean([reviewsPerRestaurant[k] for k in reviewsPerRestaurant])
avgRating = np.mean([x['rating'] for x in X['train']+X['val']+X['test']])

# %%
avgReviewsPerRestaurant, avgRating, avgReviewsPerUser
# Out:
# (3.531769971781648, 4.464798692234222, 2.9432371067142395)

# %%
X['val'][0]
# Out:
# {'business_id': '6049974fb1a0aaee3eefb0dd',
#  'user_id': '112777069092124620875',
#  'rating': 5,
#  'review_text': "It's really the best hot chicken I've had anywhere.",
#  'pics': ['AF1QipNhbk-hwCwq2O6JBZQq6UXgIpwtzr-tQFTKxMIG'],
#  'history_reviews': [['112777069092124620875_6043a4a88be5d4454df9dd76',
#    'We hand the Amish Chicken and Hangar Steak. Plus to start some Lazy Pierogi. Dessert was carrot cake and snores cheesecake.'],
#   ['112777069092124620875_6043a42bad733fba1bcfdde4',
#    'The Mezzaluna, and Tagliatelle were the standout.'],
#   ['112777069092124620875_604244e27dfa7f187183b871',
#    "Delicious horchata. Great guacamole and esquites. The cochinita pobil is one of the best things I've ever eaten. All followed by the amazing churros."],
#   ['112777069092124620875_6045a3809ced5955401d3a1e',
#    'Their Nashville hot chicken sandwich is awesome. Deviled eggs are great too.']]}

# %%
restaurantIDs = []
restaurantDict = {}
userDict = {}
userIDs = []
for x in X['train']+X['val']+X['test']:
    usersVisitedByRestaurant[x['business_id']].add(x['user_id'])
    restaurantsVisitedByUser[x['user_id']].add(x['business_id'])
    if not x['user_id'] in userIDs: 
        userIDs.append(x['user_id'])
        userDict[x['user_id']] = len(userDict)
    if not x['business_id'] in restaurantIDs: 
        restaurantIDs.append(x['business_id'])
        restaurantDict[x['business_id']] = len(restaurantDict)

# %%
# Rui = np.zeros([len(userIDs), len(restaurantIDs)])
# for x in X['train']+X['val']+X['test']:
#     Rui[userIDs.index(x['user_id'])][restaurantIDs.index(x['business_id'])] = 1

# %%
len(userIDs), len(restaurantIDs), len(X['train']+X['val'])
# Out:
# (33296, 29449, 97873)

# %%
max([len(v) for k,v in restaurantsVisitedByUser.items()]), len(usersVisitedByRestaurant.keys())
# Out:
# (46, 30831)

# %%
max([len(v) for k,v in usersVisitedByRestaurant.items()]), len(restaurantsVisitedByUser.keys())
# Out:
# (243, 36996)

# %%
len(X['train'])
# Out:
# 87013

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.1)

# %%
class LatentFactorModel(tf.keras.Model):
    def __init__(self, K, lamb):
        super(LatentFactorModel, self).__init__()
        # Initialize variables
        self.alpha = tf.Variable(0.0) 
        self.betaU = tf.Variable(tf.random.normal([len(userIDs)],stddev=0.001))
        self.betaI = tf.Variable(tf.random.normal([len(restaurantIDs)],stddev=0.001))
        self.gammaU = tf.Variable(tf.random.normal([len(userIDs),K],stddev=0.001))
        self.gammaI = tf.Variable(tf.random.normal([len(restaurantIDs),K],stddev=0.001))
        # Regularization coefficient
        self.lamb = lamb

    # Prediction for a single instance
    def predict(self, u, i):
        p = self.alpha + self.betaI[i] + self.betaU[u] + tf.tensordot(self.gammaU[u], self.gammaI[i], 1)
        return p

    # Regularizer
    def reg(self):
        return self.lamb * (tf.nn.l2_loss(self.betaU) +\
                            tf.nn.l2_loss(self.betaI) +\
                            tf.nn.l2_loss(self.gammaU) +\
                            tf.nn.l2_loss(self.gammaI))
    
    # Prediction for a sample of instances
    def predictSample(self, sampleU, sampleI):
        u = tf.convert_to_tensor(sampleU, dtype=tf.int32)
        i = tf.convert_to_tensor(sampleI, dtype=tf.int32)
        beta_u = tf.nn.embedding_lookup(self.betaU, u)
        beta_i = tf.nn.embedding_lookup(self.betaI, i)
        gamma_u = tf.nn.embedding_lookup(self.gammaU, u)
        # print(gamma_u)
        gamma_i = tf.nn.embedding_lookup(self.gammaI, i)
        pred = self.alpha + beta_u + beta_i +\
               tf.reduce_sum(tf.multiply(gamma_u, gamma_i), 1)
        return pred
    
    # Loss
    def call(self, sampleU, sampleI, sampleR):
        pred = self.predictSample(sampleU, sampleI)
        r = tf.convert_to_tensor(sampleR, dtype=tf.float32)
        return 2 * tf.nn.l2_loss(pred - r) / len(sampleR)

# %%
modelLFM = LatentFactorModel(5, 0.00001)

# %%
def trainingStep(model, interactions):
    Nsamples = 25000
    with tf.GradientTape() as tape:
        sampleU, sampleI, sampleR = [], [], []
        for _ in range(Nsamples):
            x = random.choice(interactions)
            sampleU.append(userDict[x['user_id']])
            sampleI.append(restaurantDict[x['business_id']])
            sampleR.append(x['rating'])   

        # print(sampleU)
        loss = model(sampleU,sampleI,sampleR)
        loss += model.reg()
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients((grad, var) for
                              (grad, var) in zip(gradients, model.trainable_variables)
                              if grad is not None)
    return loss.numpy()

# %%
for i in range(500):
    obj = trainingStep(modelLFM, X['train'])
    print("iteration " + str(i+1) + ", objective = " + str(obj))
# Out:
# iteration 1, objective = 20.655422
# iteration 2, objective = 18.624773
# iteration 3, objective = 16.638021
# iteration 4, objective = 14.717076
# iteration 5, objective = 12.924836
# iteration 6, objective = 11.116019
# iteration 7, objective = 9.4493065
# iteration 8, objective = 7.923042
# iteration 9, objective = 6.4753923
# iteration 10, objective = 5.1854353
# iteration 11, objective = 4.0183077
# iteration 12, objective = 3.1574912
# iteration 13, objective = 2.4483843
# iteration 14, objective = 2.0309958
# iteration 15, objective = 1.7822745
# iteration 16, objective = 1.7214575
# iteration 17, objective = 1.7763882
# iteration 18, objective = 1.8283151
# iteration 19, objective = 1.8427674
# iteration 20, objective = 1.8844432
# iteration 21, objective = 1.8542197
# iteration 22, objective = 1.7371328
# iteration 23, objective = 1.6209068
# iteration 24, objective = 1.4674484
# iteration 25, objective = 1.3208632
# iteration 26, objective = 1.2133058
# iteration 27, objective = 1.105624
# iteration 28, objective = 1.0118048
# iteration 29, objective = 0.9566637
# iteration 30, objective = 0.90739346
# iteration 31, objective = 0.87802535
# iteration 32, objective = 0.86319625
# iteration 33, objective = 0.8478832
# iteration 34, objective = 0.8383775
# iteration 35, objective = 0.831686
# iteration 36, objective = 0.8333833
# iteration 37, objective = 0.8208144
# iteration 38, objective = 0.8093951
# iteration 39, objective = 0.8023107
# iteration 40, objective = 0.7794415
# iteration 41, objective = 0.76537985
# iteration 42, objective = 0.7525599
# iteration 43, objective = 0.7366165
# iteration 44, objective = 0.7159692
# iteration 45, objective = 0.69783664
# iteration 46, objective = 0.68398076
# iteration 47, objective = 0.66844314
# iteration 48, objective = 0.65804654
# iteration 49, objective = 0.6478362
# iteration 50, objective = 0.6364637
# iteration 51, objective = 0.62591994
# iteration 52, objective = 0.6160134
# iteration 53, objective = 0.6067966
# iteration 54, objective = 0.6006091
# iteration 55, objective = 0.593709
# iteration 56, objective = 0.58475274
# iteration 57, objective = 0.5787541
# iteration 58, objective = 0.5703861
# iteration 59, objective = 0.5654563
# iteration 60, objective = 0.5582544
# iteration 61, objective = 0.5527223
# iteration 62, objective = 0.5450689
# iteration 63, objective = 0.53871894
# iteration 64, objective = 0.5352592
# iteration 65, objective = 0.53076136
# iteration 66, objective = 0.5237516
# iteration 67, objective = 0.5183464
# iteration 68, objective = 0.51645935
# iteration 69, objective = 0.51087433
# iteration 70, objective = 0.5079341
# iteration 71, objective = 0.5046754
# iteration 72, objective = 0.5000575
# iteration 73, objective = 0.497836
# iteration 74, objective = 0.49347192
# iteration 75, objective = 0.48925704
# iteration 76, objective = 0.48849988
# iteration 77, objective = 0.48407692
# iteration 78, objective = 0.48099247
# iteration 79, objective = 0.47654685
# iteration 80, objective = 0.47522002
# iteration 81, objective = 0.47186518
# iteration 82, objective = 0.4683819
# iteration 83, objective = 0.46555275
# iteration 84, objective = 0.46223515
# iteration 85, objective = 0.46092743
# iteration 86, objective = 0.4570694
# iteration 87, objective = 0.45565468
# iteration 88, objective = 0.45226622
# iteration 89, objective = 0.44876373
# iteration 90, objective = 0.44699165
# iteration 91, objective = 0.4454853
# iteration 92, objective = 0.44379622
# iteration 93, objective = 0.4418357
# iteration 94, objective = 0.43833774
# iteration 95, objective = 0.43605444
# iteration 96, objective = 0.4329845
# iteration 97, objective = 0.43112287
# iteration 98, objective = 0.42948154
# iteration 99, objective = 0.4268676
# iteration 100, objective = 0.42435682
# iteration 101, objective = 0.4223821
# iteration 102, objective = 0.4207556
# iteration 103, objective = 0.41707748
# iteration 104, objective = 0.41566277
# iteration 105, objective = 0.41305295
# iteration 106, objective = 0.41144264
# iteration 107, objective = 0.40962905
# iteration 108, objective = 0.40711322
# iteration 109, objective = 0.40628004
# iteration 110, objective = 0.40361378
# iteration 111, objective = 0.40160796
# iteration 112, objective = 0.39971265
# iteration 113, objective = 0.39743978
# iteration 114, objective = 0.39556417
# iteration 115, objective = 0.3926411
# iteration 116, objective = 0.3918662
# iteration 117, objective = 0.38923526
# iteration 118, objective = 0.38820502
# iteration 119, objective = 0.3854736
# iteration 120, objective = 0.38475925
# iteration 121, objective = 0.38171488
# iteration 122, objective = 0.38023874
# iteration 123, objective = 0.3783035
# iteration 124, objective = 0.37658525
# iteration 125, objective = 0.37475747
# iteration 126, objective = 0.37382182
# iteration 127, objective = 0.3706497
# iteration 128, objective = 0.36919317
# iteration 129, objective = 0.3685195
# iteration 130, objective = 0.36626816
# iteration 131, objective = 0.36364767
# iteration 132, objective = 0.36212042
# iteration 133, objective = 0.35988894
# iteration 134, objective = 0.35839415
# iteration 135, objective = 0.35676384
# iteration 136, objective = 0.3552034
# iteration 137, objective = 0.3538498
# iteration 138, objective = 0.352057
# iteration 139, objective = 0.35041296
# iteration 140, objective = 0.34914643
# iteration 141, objective = 0.34702423
# iteration 142, objective = 0.3459083
# iteration 143, objective = 0.3438408
# iteration 144, objective = 0.34255213
# iteration 145, objective = 0.33998853
# iteration 146, objective = 0.33982503
# iteration 147, objective = 0.3361116
# iteration 148, objective = 0.33536768
# iteration 149, objective = 0.33398235
# iteration 150, objective = 0.3326886
# iteration 151, objective = 0.33072013
# iteration 152, objective = 0.32855108
# iteration 153, objective = 0.32802004
# iteration 154, objective = 0.32636413
# iteration 155, objective = 0.32383752
# iteration 156, objective = 0.32303894
# iteration 157, objective = 0.3213213
# iteration 158, objective = 0.31936848
# iteration 159, objective = 0.31783918
# iteration 160, objective = 0.31642097
# iteration 161, objective = 0.31623748
# iteration 162, objective = 0.31443995
# iteration 163, objective = 0.3135177
# iteration 164, objective = 0.31165388
# iteration 165, objective = 0.3088276
# iteration 166, objective = 0.30812743
# iteration 167, objective = 0.30627885
# iteration 168, objective = 0.3055184
# iteration 169, objective = 0.3036841
# iteration 170, objective = 0.30197
# iteration 171, objective = 0.30106226
# iteration 172, objective = 0.29965803
# iteration 173, objective = 0.29852265
# iteration 174, objective = 0.29629457
# iteration 175, objective = 0.29581785
# iteration 176, objective = 0.29402804
# iteration 177, objective = 0.29289442
# iteration 178, objective = 0.29123116
# iteration 179, objective = 0.29131898
# iteration 180, objective = 0.28883874
# iteration 181, objective = 0.2867452
# iteration 182, objective = 0.2862141
# iteration 183, objective = 0.28508317
# iteration 184, objective = 0.2829815
# iteration 185, objective = 0.28228748
# iteration 186, objective = 0.28051797
# iteration 187, objective = 0.27933216
# iteration 188, objective = 0.27869913
# iteration 189, objective = 0.27725062
# iteration 190, objective = 0.2765947
# iteration 191, objective = 0.27456838
# iteration 192, objective = 0.27340293
# iteration 193, objective = 0.2720987
# iteration 194, objective = 0.2711264
# iteration 195, objective = 0.2699682
# iteration 196, objective = 0.26871017
# iteration 197, objective = 0.26806682
# iteration 198, objective = 0.2674615
# iteration 199, objective = 0.26505595
# iteration 200, objective = 0.26388925
# iteration 201, objective = 0.26354825
# iteration 202, objective = 0.26248193
# iteration 203, objective = 0.26065058
# iteration 204, objective = 0.2597188
# iteration 205, objective = 0.2587005
# iteration 206, objective = 0.25734484
# iteration 207, objective = 0.2563908
# iteration 208, objective = 0.25549516
# iteration 209, objective = 0.2539642
# iteration 210, objective = 0.25332648
# iteration 211, objective = 0.25246865
# iteration 212, objective = 0.25042692
# iteration 213, objective = 0.2500346
# iteration 214, objective = 0.24892734
# iteration 215, objective = 0.2475611
# iteration 216, objective = 0.24775666
# iteration 217, objective = 0.24574777
# iteration 218, objective = 0.24513485
# iteration 219, objective = 0.24383521
# iteration 220, objective = 0.24388894
# iteration 221, objective = 0.24223211
# iteration 222, objective = 0.24117997
# iteration 223, objective = 0.23947814
# iteration 224, objective = 0.23902278
# iteration 225, objective = 0.23829174
# iteration 226, objective = 0.23736708
# iteration 227, objective = 0.23630871
# iteration 228, objective = 0.23516804
# iteration 229, objective = 0.23511867
# iteration 230, objective = 0.23428959
# iteration 231, objective = 0.23274282
# iteration 232, objective = 0.2320032
# iteration 233, objective = 0.23086755
# iteration 234, objective = 0.23022778
# iteration 235, objective = 0.22829153
# iteration 236, objective = 0.22861214
# iteration 237, objective = 0.22799563
# iteration 238, objective = 0.22679423
# iteration 239, objective = 0.22656402
# iteration 240, objective = 0.22474429
# iteration 241, objective = 0.22395478
# iteration 242, objective = 0.2236144
# iteration 243, objective = 0.22274026
# iteration 244, objective = 0.22084177
# iteration 245, objective = 0.22130458
# iteration 246, objective = 0.22102994
# iteration 247, objective = 0.21934614
# iteration 248, objective = 0.21902953
# iteration 249, objective = 0.2177406
# iteration 250, objective = 0.21741137
# iteration 251, objective = 0.21620004
# iteration 252, objective = 0.21498315
# iteration 253, objective = 0.21525675
# iteration 254, objective = 0.21390142
# iteration 255, objective = 0.21331102
# iteration 256, objective = 0.21286452
# iteration 257, objective = 0.21287379
# iteration 258, objective = 0.21110499
# iteration 259, objective = 0.21141514
# iteration 260, objective = 0.21034238
# iteration 261, objective = 0.21040016
# iteration 262, objective = 0.20900083
# iteration 263, objective = 0.20758758
# iteration 264, objective = 0.20704634
# iteration 265, objective = 0.20679855
# iteration 266, objective = 0.20571345
# iteration 267, objective = 0.20440573
# iteration 268, objective = 0.20449227
# iteration 269, objective = 0.20313555
# iteration 270, objective = 0.20298311
# iteration 271, objective = 0.20294246
# iteration 272, objective = 0.20200278
# iteration 273, objective = 0.20154166
# iteration 274, objective = 0.20101401
# iteration 275, objective = 0.19982058
# iteration 276, objective = 0.19908112
# iteration 277, objective = 0.19822797
# iteration 278, objective = 0.1986776
# iteration 279, objective = 0.1969064
# iteration 280, objective = 0.19647065
# iteration 281, objective = 0.196421
# iteration 282, objective = 0.19634219
# iteration 283, objective = 0.19442213
# iteration 284, objective = 0.19576113
# iteration 285, objective = 0.19327798
# iteration 286, objective = 0.19312294
# iteration 287, objective = 0.1927646
# iteration 288, objective = 0.19168277
# iteration 289, objective = 0.19224286
# iteration 290, objective = 0.19130027
# iteration 291, objective = 0.19176245
# iteration 292, objective = 0.19050966
# iteration 293, objective = 0.18912303
# iteration 294, objective = 0.1891711
# iteration 295, objective = 0.1889204
# iteration 296, objective = 0.18896756
# iteration 297, objective = 0.18892343
# iteration 298, objective = 0.18623383
# iteration 299, objective = 0.18729565
# iteration 300, objective = 0.18659508
# iteration 301, objective = 0.18591306
# iteration 302, objective = 0.18492883
# iteration 303, objective = 0.1847288
# iteration 304, objective = 0.18434101
# iteration 305, objective = 0.1844416
# iteration 306, objective = 0.1840495
# iteration 307, objective = 0.18285182
# iteration 308, objective = 0.18299204
# iteration 309, objective = 0.18232888
# iteration 310, objective = 0.18155226
# iteration 311, objective = 0.18077397
# iteration 312, objective = 0.1809412
# iteration 313, objective = 0.17990248
# iteration 314, objective = 0.17915463
# iteration 315, objective = 0.17962776
# iteration 316, objective = 0.17886545
# iteration 317, objective = 0.17896363
# iteration 318, objective = 0.17945412
# iteration 319, objective = 0.17913537
# iteration 320, objective = 0.17859729
# iteration 321, objective = 0.17594756
# iteration 322, objective = 0.17759907
# iteration 323, objective = 0.17584807
# iteration 324, objective = 0.17619006
# iteration 325, objective = 0.17629252
# iteration 326, objective = 0.17627244
# iteration 327, objective = 0.1750429
# iteration 328, objective = 0.17476796
# iteration 329, objective = 0.17392692
# iteration 330, objective = 0.17532252
# iteration 331, objective = 0.17362465
# iteration 332, objective = 0.17380059
# iteration 333, objective = 0.17321366
# iteration 334, objective = 0.17379615
# iteration 335, objective = 0.17264763
# iteration 336, objective = 0.17242967
# iteration 337, objective = 0.17208347
# iteration 338, objective = 0.17033581
# iteration 339, objective = 0.17189088
# iteration 340, objective = 0.17072724
# iteration 341, objective = 0.16976073
# iteration 342, objective = 0.17079592
# iteration 343, objective = 0.17000781
# iteration 344, objective = 0.1702622
# iteration 345, objective = 0.16867214
# iteration 346, objective = 0.16926624
# iteration 347, objective = 0.16833119
# iteration 348, objective = 0.16843301
# iteration 349, objective = 0.1674305
# iteration 350, objective = 0.16875446
# iteration 351, objective = 0.16776864
# iteration 352, objective = 0.1672253
# iteration 353, objective = 0.16677073
# iteration 354, objective = 0.166291
# iteration 355, objective = 0.16504633
# iteration 356, objective = 0.16565144
# iteration 357, objective = 0.16580772
# iteration 358, objective = 0.16567619
# iteration 359, objective = 0.16469358
# iteration 360, objective = 0.16518101
# iteration 361, objective = 0.16509378
# iteration 362, objective = 0.16463983
# iteration 363, objective = 0.16444999
# iteration 364, objective = 0.16452307
# iteration 365, objective = 0.16466734
# iteration 366, objective = 0.16370273
# iteration 367, objective = 0.16353604
# iteration 368, objective = 0.16258985
# iteration 369, objective = 0.16234168
# iteration 370, objective = 0.16245106
# iteration 371, objective = 0.1615217
# iteration 372, objective = 0.1629704
# iteration 373, objective = 0.16172865
# iteration 374, objective = 0.1631997
# iteration 375, objective = 0.16070934
# iteration 376, objective = 0.16145276
# iteration 377, objective = 0.16085887
# iteration 378, objective = 0.16080359
# iteration 379, objective = 0.16130883
# iteration 380, objective = 0.16046986
# iteration 381, objective = 0.16125163
# iteration 382, objective = 0.15982997
# iteration 383, objective = 0.16014038
# iteration 384, objective = 0.159684
# iteration 385, objective = 0.15998548
# iteration 386, objective = 0.15866685
# iteration 387, objective = 0.15908496
# iteration 388, objective = 0.15901348
# iteration 389, objective = 0.15801081
# iteration 390, objective = 0.15739964
# iteration 391, objective = 0.15774713
# iteration 392, objective = 0.15948701
# iteration 393, objective = 0.15845825
# iteration 394, objective = 0.15694028
# iteration 395, objective = 0.15793516
# iteration 396, objective = 0.15806717
# iteration 397, objective = 0.15884735
# iteration 398, objective = 0.15863326
# iteration 399, objective = 0.15758559
# iteration 400, objective = 0.15775234
# iteration 401, objective = 0.15641278
# iteration 402, objective = 0.15622121
# iteration 403, objective = 0.15627366
# iteration 404, objective = 0.15769
# iteration 405, objective = 0.15648517
# iteration 406, objective = 0.15522848
# iteration 407, objective = 0.15548857
# iteration 408, objective = 0.15669912
# iteration 409, objective = 0.15555373
# iteration 410, objective = 0.15627708
# iteration 411, objective = 0.1553546
# iteration 412, objective = 0.15517224
# iteration 413, objective = 0.15575224
# iteration 414, objective = 0.15500505
# iteration 415, objective = 0.15414289
# iteration 416, objective = 0.15477914
# iteration 417, objective = 0.15464652
# iteration 418, objective = 0.15518436
# iteration 419, objective = 0.15300368
# iteration 420, objective = 0.15414612
# iteration 421, objective = 0.15302768
# iteration 422, objective = 0.15311746
# iteration 423, objective = 0.15428269
# iteration 424, objective = 0.15280151
# iteration 425, objective = 0.15313584
# iteration 426, objective = 0.15369764
# iteration 427, objective = 0.15284836
# iteration 428, objective = 0.15414853
# iteration 429, objective = 0.15242586
# iteration 430, objective = 0.15309182
# iteration 431, objective = 0.15263765
# iteration 432, objective = 0.15185967
# iteration 433, objective = 0.15319212
# iteration 434, objective = 0.15342171
# iteration 435, objective = 0.15398319
# iteration 436, objective = 0.15294269
# iteration 437, objective = 0.15260983
# iteration 438, objective = 0.1533567
# iteration 439, objective = 0.15384372
# iteration 440, objective = 0.151719
# iteration 441, objective = 0.15186912
# iteration 442, objective = 0.15114312
# iteration 443, objective = 0.15215844
# iteration 444, objective = 0.15261477
# iteration 445, objective = 0.1515477
# iteration 446, objective = 0.15183759
# iteration 447, objective = 0.1519906
# iteration 448, objective = 0.15103453
# iteration 449, objective = 0.15113024
# iteration 450, objective = 0.15150055
# iteration 451, objective = 0.15089427
# iteration 452, objective = 0.15162537
# iteration 453, objective = 0.15069664
# iteration 454, objective = 0.15115198
# iteration 455, objective = 0.15172602
# iteration 456, objective = 0.15149848
# iteration 457, objective = 0.15072784
# iteration 458, objective = 0.15084022
# iteration 459, objective = 0.15052065
# iteration 460, objective = 0.15162928
# iteration 461, objective = 0.15081213
# iteration 462, objective = 0.15092358
# iteration 463, objective = 0.15020168
# iteration 464, objective = 0.14970553
# iteration 465, objective = 0.15045214
# iteration 466, objective = 0.15050095
# iteration 467, objective = 0.14958128
# iteration 468, objective = 0.15084428
# iteration 469, objective = 0.14982519
# iteration 470, objective = 0.14950639
# iteration 471, objective = 0.14892581
# iteration 472, objective = 0.15004525
# iteration 473, objective = 0.15065466
# iteration 474, objective = 0.14965817
# iteration 475, objective = 0.15011448
# iteration 476, objective = 0.15120934
# iteration 477, objective = 0.14828971
# iteration 478, objective = 0.14906013
# iteration 479, objective = 0.1499522
# iteration 480, objective = 0.15014452
# iteration 481, objective = 0.14911568
# iteration 482, objective = 0.15042706
# iteration 483, objective = 0.15067291
# iteration 484, objective = 0.14971794
# iteration 485, objective = 0.14871901
# iteration 486, objective = 0.14993744
# iteration 487, objective = 0.14945519
# iteration 488, objective = 0.15004809
# iteration 489, objective = 0.14931472
# iteration 490, objective = 0.1483623
# iteration 491, objective = 0.14871196
# iteration 492, objective = 0.14914724
# iteration 493, objective = 0.14981706
# iteration 494, objective = 0.14885333
# iteration 495, objective = 0.14913073
# iteration 496, objective = 0.14977932
# iteration 497, objective = 0.15017836
# iteration 498, objective = 0.14814453
# iteration 499, objective = 0.14810638
# iteration 500, objective = 0.14844915

# %%
testU = []
testI = []
testR = []
for x in X['test']:
    testU.append(userDict[x['user_id']])
    testI.append(restaurantDict[x['business_id']])
    testR.append(x['rating']) 
pred =  modelLFM.predictSample(testU, testI).numpy()
print("MSE", 2 * tf.nn.l2_loss(testR - pred).numpy() / len(pred))
# print("Loss in test data: ",)
# Out:
# MSE 0.7229179012205612

# %%
len([x for x in X['test'] if x['user_id'] not in userIDs])
# Out:
# 0

# %%
def getIu(u, i):
    iu = [restaurantDict[item] for item in restaurantsVisitedByUser[userIDs[u]]]
    # print(iu, sampleI[t])
    if i not in iu:
        return iu
    else:
        iu.remove(i)
        return iu

# %%
b = [[1,2],[2,3,4]]
# padItemHistory(b, 5)

# %%
def padItemHistory(descriptions, maxlen):
    # for i in range(descriptions.__len__()):
    #     descriptions[i].extend([len(restaurantIDs) * (maxlen - descriptions[i].__len__())])
    # return descriptions
    hist = []
    for idx in range(len(descriptions)):
        temp = [len(restaurantIDs)] * maxlen
        for t in range(len(descriptions[idx])):
            temp[t] = descriptions[idx][t]
        hist.append(temp)
    return hist

# %%
a = tf.convert_to_tensor([[1,2,3],[2,3,4],[1,1,1],[2,2,2]])
# b = tf.convert_to_tensor([[1,1]])
# z = tf.convert_to_tensor([1,2,3])
# # tf.matmul(a,tf.transpose(a))
# tf.reduce_sum(tf.multiply(a, tf.transpose(a, perm=[1,0,2])),2)
# z[0] = tf.add(z[0], tf.reduce_sum(tf.multiply(a,b)))
# tf.stack([[1,2,3],[1,2]])
tf.divide(a, [2])
# tf.reduce_sum(tf.gather([[1,2,3],[2,3,4],[1,1,1],[2,2,2]], [[0,1,2],[0,1,3]]), 1), tf.gather([[1,2,3],[2,3,4],[1,1,1],[2,2,2]], [[0,2],[1,3]])
# Out:
# <tf.Tensor: shape=(4, 3), dtype=float64, numpy=
# array([[0.5, 1. , 1.5],
#        [1. , 1.5, 2. ],
#        [0.5, 0.5, 0.5],
#        [1. , 1. , 1. ]])>

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.1)

# %%
class FactoredItemSimModel(tf.keras.Model):
    def __init__(self, K, lamb):
        super(FactoredItemSimModel, self).__init__()
        # Initialize variables
        self.alpha = tf.Variable(0.0) 
        self.betaU = tf.Variable(tf.random.normal([len(userIDs)],stddev=0.001))
        self.betaI = tf.Variable(tf.random.normal([len(restaurantIDs)],stddev=0.001))
        self.gammaU = tf.Variable(tf.random.normal([len(restaurantIDs),K],stddev=0.001))
        self.gammaI = tf.Variable(tf.random.normal([len(restaurantIDs),K],stddev=0.001))
        self.mask = tf.Variable(tf.random.normal([1,K],stddev=0.001))
        # Regularization coefficient
        self.lamb = lamb

    # Prediction for a single instance
    def predict(self, u, i):
        p = self.alpha + self.betaI[i] + self.betaU[u] 
        q = 0
        for j in getIu(u, i):
            # if j != i:
            q += tf.tensordot(self.gammaU[j], self.gammaI[i], 1)
        return p + q / (len(restaurantsVisitedByUser[userIDs[u]])-1)

    # Regularizer
    def reg(self):
        return self.lamb * (tf.nn.l2_loss(self.betaU) +\
                            tf.nn.l2_loss(self.betaI) +\
                            # tf.nn.l2_loss(self.gammaU) +\
                            tf.nn.l2_loss(self.gammaI))
    
    # Prediction for a sample of instances
    def predictSample(self, sampleU, sampleI, itemHistory):
        u = tf.convert_to_tensor(sampleU, dtype=tf.int32)
        i = tf.convert_to_tensor(sampleI, dtype=tf.int32)
        beta_u = tf.nn.embedding_lookup(self.betaU, u)
        beta_i = tf.nn.embedding_lookup(self.betaI, i)

        gamma_i = tf.nn.embedding_lookup(self.gammaI, i)
        gamma_u = tf.concat([self.gammaU, self.mask], axis=0)
        

        # idx = [getIu(sampleU[t].numpy()) if sampleI[t] not in getIu(sampleU[t].numpy()) else getIu(sampleU[t].numpy()).remove(sampleI[t]) for t in range(len(sampleU))]
        # print(gamma_u, itemHistory)
        # print(tf.gather(gamma_u, itemHistory))
        # print(tf.reduce_sum(tf.gather(gamma_u,idx[0]), 1))
        neighbors = tf.reduce_sum(tf.gather(gamma_u, itemHistory) ,1)
        # neighbors = tf.convert_to_tensor([tf.reduce_sum(tf.gather(gamma_u,index), 1) for index in idx])
        # print(neighbors, gamma_i)
        pred = self.alpha + beta_u + beta_i + tf.divide(tf.reduce_sum(tf.multiply(neighbors, gamma_i), 1), [len(itemHistory[0])])      
        return pred

        # reverse_identity = tf.ones([len(restaurantIDs), len(restaurantIDs)]) - tf.eye(len(restaurantIDs), len(restaurantIDs))
        # gamma_ij = tf.multiply(reverse_identity, tf.matmul(self.gammaI, tf.transpose(self.gammaI)))
        # print(gamma_ij.shape)
        # Xui = tf.matmul(tf.gather(Rui, indices=sampleU), gamma_ij)
        # return pred + tf.reduce_sum(tf.multiply(Xui, tf.transpose(tf.one_hot(sampleI, len(sampleU)))), 1)
        
        
        # gamma_ui = []
        # for t in range(len(sampleU)):
        #     sampleJ = getIu(sampleU[t])
        #     if sampleI[t] in sampleJ:
        #         sampleJ.remove(sampleI[t])
        #     j = tf.convert_to_tensor(sampleJ, dtype=tf.int32)    
        #     gamma_j = tf.nn.embedding_lookup(self.gammaI, j)
        #     gamma_i = tf.nn.embedding_lookup(self.gammaI, sampleI[t])
        #     gamma_ui.append(tf.reduce_sum(tf.multiply(gamma_j, gamma_i)))
        # return pred + tf.stack(gamma_ui)
    
    # Loss
    def call(self, sampleU, sampleI, sampleR, itemHistory):
        pred = self.predictSample(sampleU, sampleI, itemHistory)
        # pred = tf.convert_to_tensor([self.predict(sampleU[t], sampleI[t]) for t in range(len(sampleU))])
        r = tf.convert_to_tensor(sampleR, dtype=tf.float32)
        return 2 * tf.nn.l2_loss(pred - r) / len(sampleR)

# %%
modelFSIM = FactoredItemSimModel(5, 0.0001)

# %%
def trainingStep(model, interactions):
    Nsamples = 25000
    with tf.GradientTape() as tape:
        sampleU, sampleI, sampleR, itemHistory, histLen = [], [], [], [], []
        for _ in range(Nsamples):
            x = random.choice(interactions)
            sampleU.append(userDict[x['user_id']])
            sampleI.append(restaurantDict[x['business_id']])
            # idx = []
            # for t in range(len(sampleU)):
            itemHistory.append(getIu(sampleU[-1], sampleI[-1]))
            # itemHistory.append(idx)
            histLen.append(len(itemHistory[-1]))
            sampleR.append(x['rating'])  
        # print(sampleU) 
        itemHistory = padItemHistory(itemHistory, max(histLen))
        # print(max(histLen))
        # print(itemHistory)
        # print(padItemHistory(itemHistory, max(histLen) ))
        loss = model(sampleU,sampleI,sampleR, itemHistory)
        loss += model.reg()
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients((grad, var) for
                              (grad, var) in zip(gradients, model.trainable_variables)
                              if grad is not None)
    return loss.numpy()

# %%
for i in range(500):
    obj = trainingStep(modelFSIM, X['train']+X['val'])
    print("iteration " + str(i+1) + ", objective = " + str(obj))
# Out:
# iteration 1, objective = 20.596462
# iteration 2, objective = 18.656736
# iteration 3, objective = 16.813566
# iteration 4, objective = 14.838133
# iteration 5, objective = 12.844305
# iteration 6, objective = 10.838593
# iteration 7, objective = 8.8012
# iteration 8, objective = 6.91752
# iteration 9, objective = 5.4150777
# iteration 10, objective = 4.231898
# iteration 11, objective = 3.6448126
# iteration 12, objective = 3.7463355
# iteration 13, objective = 4.2071586
# iteration 14, objective = 4.623149
# iteration 15, objective = 4.7378244
# iteration 16, objective = 4.513008
# iteration 17, objective = 4.0967226
# iteration 18, objective = 3.6270978
# iteration 19, objective = 3.2342253
# iteration 20, objective = 2.9702868
# iteration 21, objective = 2.820657
# iteration 22, objective = 2.8055444
# iteration 23, objective = 2.8111608
# iteration 24, objective = 2.8532157
# iteration 25, objective = 2.9105415
# iteration 26, objective = 2.9139771
# iteration 27, objective = 2.906792
# iteration 28, objective = 2.8457317
# iteration 29, objective = 2.7198014
# iteration 30, objective = 2.622387
# iteration 31, objective = 2.498388
# iteration 32, objective = 2.3599687
# iteration 33, objective = 2.2543972
# iteration 34, objective = 2.177371
# iteration 35, objective = 2.1003256
# iteration 36, objective = 2.059173
# iteration 37, objective = 2.0173287
# iteration 38, objective = 1.9844214
# iteration 39, objective = 1.9565604
# iteration 40, objective = 1.9102054
# iteration 41, objective = 1.8709028
# iteration 42, objective = 1.7996094
# iteration 43, objective = 1.7506547
# iteration 44, objective = 1.6864133
# iteration 45, objective = 1.6322763
# iteration 46, objective = 1.5835282
# iteration 47, objective = 1.5661618
# iteration 48, objective = 1.5228195
# iteration 49, objective = 1.4900306
# iteration 50, objective = 1.4743844
# iteration 51, objective = 1.4409871
# iteration 52, objective = 1.4193108
# iteration 53, objective = 1.3751256
# iteration 54, objective = 1.3460507
# iteration 55, objective = 1.3286111
# iteration 56, objective = 1.2920048
# iteration 57, objective = 1.2646626
# iteration 58, objective = 1.2563554
# iteration 59, objective = 1.2248335
# iteration 60, objective = 1.2016803
# iteration 61, objective = 1.1731955
# iteration 62, objective = 1.1646862
# iteration 63, objective = 1.1313632
# iteration 64, objective = 1.1385696
# iteration 65, objective = 1.1167185
# iteration 66, objective = 1.1012487
# iteration 67, objective = 1.0669373
# iteration 68, objective = 1.0648308
# iteration 69, objective = 1.0586166
# iteration 70, objective = 1.0395122
# iteration 71, objective = 1.039747
# iteration 72, objective = 1.0314226
# iteration 73, objective = 1.0034461
# iteration 74, objective = 1.0066861
# iteration 75, objective = 0.9854449
# iteration 76, objective = 0.97925884
# iteration 77, objective = 0.97427833
# iteration 78, objective = 0.96298337
# iteration 79, objective = 0.94676614
# iteration 80, objective = 0.9413096
# iteration 81, objective = 0.93867874
# iteration 82, objective = 0.940187
# iteration 83, objective = 0.92636466
# iteration 84, objective = 0.92417353
# iteration 85, objective = 0.9100075
# iteration 86, objective = 0.90278184
# iteration 87, objective = 0.9040362
# iteration 88, objective = 0.9012712
# iteration 89, objective = 0.8784763
# iteration 90, objective = 0.8756349
# iteration 91, objective = 0.88686144
# iteration 92, objective = 0.8924909
# iteration 93, objective = 0.87695956
# iteration 94, objective = 0.8572755
# iteration 95, objective = 0.85273206
# iteration 96, objective = 0.8535147
# iteration 97, objective = 0.8355179
# iteration 98, objective = 0.84718376
# iteration 99, objective = 0.8405391
# iteration 100, objective = 0.84110224
# iteration 101, objective = 0.8332956
# iteration 102, objective = 0.82720935
# iteration 103, objective = 0.8355127
# iteration 104, objective = 0.82255185
# iteration 105, objective = 0.8299725
# iteration 106, objective = 0.81966424
# iteration 107, objective = 0.8085562
# iteration 108, objective = 0.8029873
# iteration 109, objective = 0.7994708
# iteration 110, objective = 0.7878969
# iteration 111, objective = 0.78920245
# iteration 112, objective = 0.7850481
# iteration 113, objective = 0.7946461
# iteration 114, objective = 0.7847754
# iteration 115, objective = 0.78349686
# iteration 116, objective = 0.7703427
# iteration 117, objective = 0.7700949
# iteration 118, objective = 0.7578747
# iteration 119, objective = 0.7555742
# iteration 120, objective = 0.76772755
# iteration 121, objective = 0.7497673
# iteration 122, objective = 0.7451961
# iteration 123, objective = 0.7462802
# iteration 124, objective = 0.74842846
# iteration 125, objective = 0.74115115
# iteration 126, objective = 0.7441603
# iteration 127, objective = 0.7368609
# iteration 128, objective = 0.7237036
# iteration 129, objective = 0.716347
# iteration 130, objective = 0.70888346
# iteration 131, objective = 0.7100539
# iteration 132, objective = 0.70881325
# iteration 133, objective = 0.7157215
# iteration 134, objective = 0.71198773
# iteration 135, objective = 0.69747454
# iteration 136, objective = 0.70335335
# iteration 137, objective = 0.6992571
# iteration 138, objective = 0.6913542
# iteration 139, objective = 0.6877939
# iteration 140, objective = 0.6932662
# iteration 141, objective = 0.67811954
# iteration 142, objective = 0.6717974
# iteration 143, objective = 0.66939914
# iteration 144, objective = 0.6703621
# iteration 145, objective = 0.6768532
# iteration 146, objective = 0.6628817
# iteration 147, objective = 0.6620834
# iteration 148, objective = 0.66099846
# iteration 149, objective = 0.66805226
# iteration 150, objective = 0.65101165
# iteration 151, objective = 0.6418396
# iteration 152, objective = 0.6608106
# iteration 153, objective = 0.6467989
# iteration 154, objective = 0.64430684
# iteration 155, objective = 0.6425433
# iteration 156, objective = 0.6332804
# iteration 157, objective = 0.6363435
# iteration 158, objective = 0.63707745
# iteration 159, objective = 0.63352925
# iteration 160, objective = 0.63472337
# iteration 161, objective = 0.62566286
# iteration 162, objective = 0.6284653
# iteration 163, objective = 0.6265925
# iteration 164, objective = 0.62286973
# iteration 165, objective = 0.61869824
# iteration 166, objective = 0.60797846
# iteration 167, objective = 0.6165345
# iteration 168, objective = 0.6044051
# iteration 169, objective = 0.6035758
# iteration 170, objective = 0.60450447
# iteration 171, objective = 0.5917758
# iteration 172, objective = 0.6018454
# iteration 173, objective = 0.5993318
# iteration 174, objective = 0.5910508
# iteration 175, objective = 0.5963647
# iteration 176, objective = 0.5969707
# iteration 177, objective = 0.58917284
# iteration 178, objective = 0.58946615
# iteration 179, objective = 0.59084886
# iteration 180, objective = 0.5955628
# iteration 181, objective = 0.57703495
# iteration 182, objective = 0.58579195
# iteration 183, objective = 0.57121694
# iteration 184, objective = 0.5709985
# iteration 185, objective = 0.5699178
# iteration 186, objective = 0.5686943
# iteration 187, objective = 0.5637006
# iteration 188, objective = 0.5680957
# iteration 189, objective = 0.5765012
# iteration 190, objective = 0.5645116
# iteration 191, objective = 0.5687094
# iteration 192, objective = 0.5662389
# iteration 193, objective = 0.5608495
# iteration 194, objective = 0.55363834
# iteration 195, objective = 0.5468885
# iteration 196, objective = 0.5673558
# iteration 197, objective = 0.55883884
# iteration 198, objective = 0.54204607
# iteration 199, objective = 0.55222327
# iteration 200, objective = 0.5513712
# iteration 201, objective = 0.5408082
# iteration 202, objective = 0.5524732
# iteration 203, objective = 0.5594554
# iteration 204, objective = 0.5545102
# iteration 205, objective = 0.54711246
# iteration 206, objective = 0.54507756
# iteration 207, objective = 0.5447649
# iteration 208, objective = 0.5464434
# iteration 209, objective = 0.5408798
# iteration 210, objective = 0.536857
# iteration 211, objective = 0.5456506
# iteration 212, objective = 0.54894686
# iteration 213, objective = 0.5359545
# iteration 214, objective = 0.54026675
# iteration 215, objective = 0.5417005
# iteration 216, objective = 0.5341989
# iteration 217, objective = 0.52842665
# iteration 218, objective = 0.5418741
# iteration 219, objective = 0.52895045
# iteration 220, objective = 0.5259614
# iteration 221, objective = 0.53119075
# iteration 222, objective = 0.5352717
# iteration 223, objective = 0.53508
# iteration 224, objective = 0.53156245
# iteration 225, objective = 0.54409033
# iteration 226, objective = 0.5420021
# iteration 227, objective = 0.5215972
# iteration 228, objective = 0.5283406
# iteration 229, objective = 0.5233469
# iteration 230, objective = 0.5273619
# iteration 231, objective = 0.52998066
# iteration 232, objective = 0.51215905
# iteration 233, objective = 0.52736664
# iteration 234, objective = 0.53095704
# iteration 235, objective = 0.5317614
# iteration 236, objective = 0.5291885
# iteration 237, objective = 0.5287708
# iteration 238, objective = 0.51666856
# iteration 239, objective = 0.5277493
# iteration 240, objective = 0.51376086
# iteration 241, objective = 0.5282546
# iteration 242, objective = 0.51318824
# iteration 243, objective = 0.513582
# iteration 244, objective = 0.5190782
# iteration 245, objective = 0.5145906
# iteration 246, objective = 0.52539116
# iteration 247, objective = 0.52338195
# iteration 248, objective = 0.52112913
# iteration 249, objective = 0.5205994
# iteration 250, objective = 0.5144229
# iteration 251, objective = 0.52047735
# iteration 252, objective = 0.52081907
# iteration 253, objective = 0.521403
# iteration 254, objective = 0.5186823
# iteration 255, objective = 0.51657456
# iteration 256, objective = 0.5232746
# iteration 257, objective = 0.5172287
# iteration 258, objective = 0.51970196
# iteration 259, objective = 0.51856244
# iteration 260, objective = 0.5187349
# iteration 261, objective = 0.5145303
# iteration 262, objective = 0.5117579
# iteration 263, objective = 0.51324356
# iteration 264, objective = 0.51881593
# iteration 265, objective = 0.5178648
# iteration 266, objective = 0.52115655
# iteration 267, objective = 0.52431184
# iteration 268, objective = 0.528013
# iteration 269, objective = 0.5034071
# iteration 270, objective = 0.515357
# iteration 271, objective = 0.5114585
# iteration 272, objective = 0.52486026
# iteration 273, objective = 0.51709604
# iteration 274, objective = 0.51897115
# iteration 275, objective = 0.5188812
# iteration 276, objective = 0.51982415
# iteration 277, objective = 0.50677735
# iteration 278, objective = 0.50768375
# iteration 279, objective = 0.5112761
# iteration 280, objective = 0.5224941
# iteration 281, objective = 0.5183461
# iteration 282, objective = 0.5143721
# iteration 283, objective = 0.51322275
# iteration 284, objective = 0.5108827
# iteration 285, objective = 0.50680983
# iteration 286, objective = 0.503689
# iteration 287, objective = 0.5070693
# iteration 288, objective = 0.51058185
# iteration 289, objective = 0.52434355
# iteration 290, objective = 0.51778316
# iteration 291, objective = 0.52494794
# iteration 292, objective = 0.51106447
# iteration 293, objective = 0.50747395
# iteration 294, objective = 0.5003412
# iteration 295, objective = 0.50659347
# iteration 296, objective = 0.5030282
# iteration 297, objective = 0.5147247
# iteration 298, objective = 0.52339387
# iteration 299, objective = 0.5079031
# iteration 300, objective = 0.5270168
# iteration 301, objective = 0.529337
# iteration 302, objective = 0.51150537
# iteration 303, objective = 0.5136718
# iteration 304, objective = 0.5170285
# iteration 305, objective = 0.50809956
# iteration 306, objective = 0.5072937
# iteration 307, objective = 0.51160663
# iteration 308, objective = 0.5131812
# iteration 309, objective = 0.5191452
# iteration 310, objective = 0.5085119
# iteration 311, objective = 0.5140027
# iteration 312, objective = 0.5152753
# iteration 313, objective = 0.5054327
# iteration 314, objective = 0.5136341
# iteration 315, objective = 0.50109947
# iteration 316, objective = 0.51277745
# iteration 317, objective = 0.518085
# iteration 318, objective = 0.5028759
# iteration 319, objective = 0.51291317
# iteration 320, objective = 0.50993675
# iteration 321, objective = 0.50975394
# iteration 322, objective = 0.5092581
# iteration 323, objective = 0.5056415
# iteration 324, objective = 0.5089047
# iteration 325, objective = 0.51544285
# iteration 326, objective = 0.5094259
# iteration 327, objective = 0.5015645
# iteration 328, objective = 0.50773007
# iteration 329, objective = 0.50714517
# iteration 330, objective = 0.5098548
# iteration 331, objective = 0.50216645
# iteration 332, objective = 0.49730247
# iteration 333, objective = 0.5036446
# iteration 334, objective = 0.5109428
# iteration 335, objective = 0.50849605
# iteration 336, objective = 0.5164739
# iteration 337, objective = 0.5093162
# iteration 338, objective = 0.49452746
# iteration 339, objective = 0.5094666
# iteration 340, objective = 0.5060689
# iteration 341, objective = 0.5121446
# iteration 342, objective = 0.5005502
# iteration 343, objective = 0.5085675
# iteration 344, objective = 0.5100244
# iteration 345, objective = 0.4978659
# iteration 346, objective = 0.5129935
# iteration 347, objective = 0.5140193
# iteration 348, objective = 0.5070237
# iteration 349, objective = 0.5086566
# iteration 350, objective = 0.50262904
# iteration 351, objective = 0.5167808
# iteration 352, objective = 0.5037439
# iteration 353, objective = 0.49710894
# iteration 354, objective = 0.5052707
# iteration 355, objective = 0.49784005
# iteration 356, objective = 0.49901116
# iteration 357, objective = 0.50938416
# iteration 358, objective = 0.50094014
# iteration 359, objective = 0.50095916
# iteration 360, objective = 0.504174
# iteration 361, objective = 0.50844574
# iteration 362, objective = 0.49615926
# iteration 363, objective = 0.4935174
# iteration 364, objective = 0.50879025
# iteration 365, objective = 0.50288415
# iteration 366, objective = 0.5048455
# iteration 367, objective = 0.49947086
# iteration 368, objective = 0.49989972
# iteration 369, objective = 0.50470877
# iteration 370, objective = 0.49629766
# iteration 371, objective = 0.5002675
# iteration 372, objective = 0.4993049
# iteration 373, objective = 0.50848633
# iteration 374, objective = 0.5055132
# iteration 375, objective = 0.49075687
# iteration 376, objective = 0.50691843
# iteration 377, objective = 0.502313
# iteration 378, objective = 0.5058211
# iteration 379, objective = 0.49227202
# iteration 380, objective = 0.5005032
# iteration 381, objective = 0.5025192
# iteration 382, objective = 0.51516306
# iteration 383, objective = 0.5060295
# iteration 384, objective = 0.5035011
# iteration 385, objective = 0.51344764
# iteration 386, objective = 0.50955296
# iteration 387, objective = 0.51193345
# iteration 388, objective = 0.50981665
# iteration 389, objective = 0.5007139
# iteration 390, objective = 0.5087668
# iteration 391, objective = 0.5009319
# iteration 392, objective = 0.49211028
# iteration 393, objective = 0.50274014
# iteration 394, objective = 0.5099108
# iteration 395, objective = 0.50322896
# iteration 396, objective = 0.5120642
# iteration 397, objective = 0.5050687
# iteration 398, objective = 0.50410676
# iteration 399, objective = 0.4984453
# iteration 400, objective = 0.49582565
# iteration 401, objective = 0.5055735
# iteration 402, objective = 0.5016539
# iteration 403, objective = 0.50834656
# iteration 404, objective = 0.4997699
# iteration 405, objective = 0.49656147
# iteration 406, objective = 0.5055728
# iteration 407, objective = 0.507326
# iteration 408, objective = 0.5036315
# iteration 409, objective = 0.4993958
# iteration 410, objective = 0.49833524
# iteration 411, objective = 0.50791544
# iteration 412, objective = 0.5100874
# iteration 413, objective = 0.5036175
# iteration 414, objective = 0.501081
# iteration 415, objective = 0.50368065
# iteration 416, objective = 0.4905942
# iteration 417, objective = 0.5055678
# iteration 418, objective = 0.49893972
# iteration 419, objective = 0.50506526
# iteration 420, objective = 0.501405
# iteration 421, objective = 0.50610125
# iteration 422, objective = 0.50303864
# iteration 423, objective = 0.5008142
# iteration 424, objective = 0.50281364
# iteration 425, objective = 0.4979232
# iteration 426, objective = 0.49775064
# iteration 427, objective = 0.4893235
# iteration 428, objective = 0.49520063
# iteration 429, objective = 0.5032205
# iteration 430, objective = 0.49119544
# iteration 431, objective = 0.49114692
# iteration 432, objective = 0.50227284
# iteration 433, objective = 0.49739462
# iteration 434, objective = 0.50406766
# iteration 435, objective = 0.5029019
# iteration 436, objective = 0.4958579
# iteration 437, objective = 0.50609964
# iteration 438, objective = 0.49101126
# iteration 439, objective = 0.4906906
# iteration 440, objective = 0.49218124
# iteration 441, objective = 0.50190663
# iteration 442, objective = 0.4959011
# iteration 443, objective = 0.49838322
# iteration 444, objective = 0.5001798
# iteration 445, objective = 0.49438673
# iteration 446, objective = 0.48847947
# iteration 447, objective = 0.49573666
# iteration 448, objective = 0.4992255
# iteration 449, objective = 0.49681
# iteration 450, objective = 0.48963377
# iteration 451, objective = 0.4916485
# iteration 452, objective = 0.49029619
# iteration 453, objective = 0.49447778
# iteration 454, objective = 0.4973213
# iteration 455, objective = 0.49363568
# iteration 456, objective = 0.49816772
# iteration 457, objective = 0.49282467
# iteration 458, objective = 0.48949027
# iteration 459, objective = 0.5047493
# iteration 460, objective = 0.49633443
# iteration 461, objective = 0.4985969
# iteration 462, objective = 0.48611218
# iteration 463, objective = 0.492413
# iteration 464, objective = 0.4965168
# iteration 465, objective = 0.49233574
# iteration 466, objective = 0.49279875
# iteration 467, objective = 0.498425
# iteration 468, objective = 0.48559475
# iteration 469, objective = 0.4883659
# iteration 470, objective = 0.49415675
# iteration 471, objective = 0.48547202
# iteration 472, objective = 0.49047744
# iteration 473, objective = 0.4946676
# iteration 474, objective = 0.48162186
# iteration 475, objective = 0.49468464
# iteration 476, objective = 0.4956439
# iteration 477, objective = 0.49081254
# iteration 478, objective = 0.49351475
# iteration 479, objective = 0.49589425
# iteration 480, objective = 0.4852032
# iteration 481, objective = 0.49235135
# iteration 482, objective = 0.48902905
# iteration 483, objective = 0.49096507
# iteration 484, objective = 0.49210384
# iteration 485, objective = 0.4832725
# iteration 486, objective = 0.49217266
# iteration 487, objective = 0.47941905
# iteration 488, objective = 0.49032205
# iteration 489, objective = 0.49296165
# iteration 490, objective = 0.49226052
# iteration 491, objective = 0.49834082
# iteration 492, objective = 0.500138
# iteration 493, objective = 0.49711335
# iteration 494, objective = 0.48706895
# iteration 495, objective = 0.4889169
# iteration 496, objective = 0.48517984
# iteration 497, objective = 0.4853258
# iteration 498, objective = 0.48242962
# iteration 499, objective = 0.48658353
# iteration 500, objective = 0.48321664

# %%
testU = []
testI = []
testR = []
# history = []
# histLen = []
for x in X['test']:
    testU.append(userDict[x['user_id']])
    testI.append(restaurantDict[x['business_id']])
    testR.append(x['rating']) 
    # history.append(getIu(testU[-1], testI[-1]))
    # histLen.append(len(history[-1]))
# history = padItemHistory(history, max(histLen))
    
pred =  [modelFSIM.predict(testU[t], testI[t]) for t in range(len(X['test']))]
pred = tf.convert_to_tensor(pred)
print("MSE", 2 * tf.nn.l2_loss(testR - pred).numpy() / len(pred))
# print("Loss in test data: ",)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jayni\OneDrive\Desktop\acads\CSE258\Assignment2\assignment2.ipynb Cell 31 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=3'>4</a> # history = []
#       <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=4'>5</a> # histLen = []
#       <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=5'>6</a> for x in X['test']:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=6'>7</a>     testU.append(userDict[x['user_id']])
#       <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=7'>8</a>     testI.append(restaurantDict[x['business_id']])
#       <a href='vscode-notebook-cell:/c%3A/Users/jayni/OneDrive/Desktop/acads/CSE258/Assignment2/assignment2.ipynb#X52sZmlsZQ%3D%3D?line=8'>9</a>     testR.append(x['rating'])
#
# KeyError: '108919790647235091207'
